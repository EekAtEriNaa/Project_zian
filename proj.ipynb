# %%
import requests
from bs4 import BeautifulSoup

# %%
from random import randint, random
from time import sleep

def try_get_page_from_server(page_num):
    
    sleep(randint(0, 3) + random()) # чтобы спать случайное число времени и наш айпи не залочили
    
    link = f'https://www.cian.ru/cat.php?deal_type=sale&engine_version=2&object_type%5B0%5D=100&offer_type=flat&p={page_num}&region=1&room1=1'
    page = requests.get(link, headers={'Browser': 'Firefox'})
    if page.status_code != 200:
        return None
    else:
        soup = BeautifulSoup(page.content, 'html.parser')
        return soup

# %%
def try_find_tag(soup_object, tag, params, v=False):
    """
    Функция для получения информации о теге (для простых тегов, которые имею уникальные атрибуты типа class и др)
    """
    try:
        res = soup_object.find(tag, params)
        return res.text
    except Exception as E:
        if v:
            print(E)
        return res
    
def try_find_places(soup_object, tag, params):
    """
    Функция для получения информации о округе, районе и метро
    """
    district = None
    area = None
    metro = None

    res = soup_object.find_all(tag, params)
    for elem in res:
        text = elem.text
        if "АО" in text:
            district = text
        elif "р-н" in text:
            area = text
        elif "м." in text:
            metro = text

    return district, area, metro

# %%
def get_page_data(soup, global_data_list):
    """
    Функция, которая принимает soup object для веб-странички, парсит её и возвращает инорфмацию в виде списка
    """
    
    for flat_info, aside_block in zip(soup.find_all("div", attrs={'class':"_93444fe79c--container--kZeLu _93444fe79c--link--DqDOy"}),
                                     soup.find_all("div", attrs={'class':"_93444fe79c--container--kZeLu _93444fe79c--agent-cont--iStzo"})):

        # число комнат, метраж, этажи
        try:
            data = try_find_tag(flat_info, "span", {'class': ""})
            room, meters, floor = data.split(', ')

            nrooms = room.split('-')[0] # число комнат
            meters = meters.split()[0] # метраж
            if "кв." in room:
                flat_or_appart = 'F'
            elif "апарт." in room:
                flat_or_appart = 'A'
            else:
                flat_or_appart = None

            floor, floors_total = floor.split()[0].split('/') # на каком этаже квартира и сколько этажей в доме

        except Exception as E:
            # print(E)
            nrooms, meters, floor, floors_total, flat_or_appart = None, None, None, None, None

        #print(try_find_tag(flat_info, "span", {'data-mark': "OfferSubtitle"}))

        # жилой комплекс
        try:
            zh_comp = try_find_tag(flat_info, "a", {'class': "_93444fe79c--jk--dIktL"})
        except Exception as E:
            # print(E)
            zh_comp = None

        # сдан ли дом. срок сдачи.
        try:
            deadline = try_find_tag(flat_info, "span", {'data-mark': "Deadline"})
        except Exception as E:
            # print(E)
            deadline = None

        # сколько до метро
        try:
            to_metro = try_find_tag(flat_info, "div", {'class': "_93444fe79c--remoteness--q8IXp"})
        except Exception as E:
            # print(E)
            to_metro = None

        # округ, район, метро
        try:
            district, area, metro = try_find_places(flat_info, "a", {'class': "_93444fe79c--link--NQlVc"})
        except Exception as E:
            # print(E)
            district, area, metro = None, None, None

        # цена 
        try:
            mainprice = "".join(try_find_tag(flat_info, "span", {'data-mark': "MainPrice"}).split()[:-1])
        except Exception as E:
            # print(E)
            mainprice = None

        # цена за кв метр
        try:
            price_per_sq_m = "".join(try_find_tag(flat_info, "p", {'data-mark': "PriceInfo"}).split()[:-1])
        except Exception as E:
            # print(E)
            price_per_sq_m = None

        # с отделкой или без (в основном без отделки)
        try:
            otdelka = try_find_tag(flat_info, "span", {'class': "_93444fe79c--label--fCs_v _93444fe79c--color_black_100--kPHhJ _93444fe79c--background_gray6_100--VAXKA"})
        except Exception as E:
            # print(E)
            otdelka = None

        # застройщик
        try:
            developer = try_find_tag(aside_block, "span", {'class': "_93444fe79c--color_current_color--gpi6p _93444fe79c--lineHeight_6u--A1GMI _93444fe79c--fontWeight_bold--ePDnv _93444fe79c--fontSize_16px--RB9YW _93444fe79c--display_block--pDAEx _93444fe79c--text--g9xAG"})
        except Exception as E:
            # print(E)
            developer = None
        
        global_data_list.append([nrooms, meters, floor, floors_total, flat_or_appart, zh_comp, deadline, to_metro,  district, area, metro, mainprice, price_per_sq_m, otdelka, developer])

# %%
data_all = []

page = 1
soup = try_get_page_from_server(page)

while soup is not None:
    print(f'Parsing page num {page}')
    get_page_data(soup, data_all)
    page += 1
    soup = try_get_page_from_server(page)
# Out:
# Parsing page num 1
# Parsing page num 2
# Parsing page num 3
# Parsing page num 4
# Parsing page num 5
# Parsing page num 6
# Parsing page num 7
# Parsing page num 8
# Parsing page num 9
# Parsing page num 10
# Parsing page num 11
# Parsing page num 12
# Parsing page num 13
# Parsing page num 14
# Parsing page num 15
# Parsing page num 16
# Parsing page num 17
# Parsing page num 18
# Parsing page num 19
# Parsing page num 20
# Parsing page num 21
# Parsing page num 22
# Parsing page num 23
# Parsing page num 24
# Parsing page num 25
# Parsing page num 26
# Parsing page num 27
# Parsing page num 28
# Parsing page num 29
# Parsing page num 30
# Parsing page num 31
# Parsing page num 32
# Parsing page num 33
# Parsing page num 34
# Parsing page num 35
# Parsing page num 36
# Parsing page num 37
# Parsing page num 38
# Parsing page num 39
# Parsing page num 40
# Parsing page num 41
# Parsing page num 42
# Parsing page num 43
# Parsing page num 44
# Parsing page num 45
# Parsing page num 46
# Parsing page num 47
# Parsing page num 48
# Parsing page num 49
# Parsing page num 50
# Parsing page num 51
# Parsing page num 52
# Parsing page num 53
# Parsing page num 54
# Parsing page num 55
# Parsing page num 56
# Parsing page num 57
# Parsing page num 58
# Parsing page num 59
# Parsing page num 60
# Parsing page num 61
# Parsing page num 62
# Parsing page num 63
# Parsing page num 64
# Parsing page num 65
# Parsing page num 66
# Parsing page num 67
# Parsing page num 68
# Parsing page num 69
# Parsing page num 70
# Parsing page num 71
# Parsing page num 72
# Parsing page num 73
# Parsing page num 74
# Parsing page num 75
# Parsing page num 76
# Parsing page num 77
# Parsing page num 78
# Parsing page num 79
# Parsing page num 80
# Parsing page num 81
# Parsing page num 82
# Parsing page num 83
# Parsing page num 84
# Parsing page num 85
# Parsing page num 86
# Parsing page num 87
# Parsing page num 88
# Parsing page num 89
# Parsing page num 90
# Parsing page num 91
# Parsing page num 92
# Parsing page num 93
# Parsing page num 94
# Parsing page num 95
# Parsing page num 96
# Parsing page num 97
# Parsing page num 98
# Parsing page num 99
# Parsing page num 100
# Parsing page num 101
# Parsing page num 102
# Parsing page num 103
# Parsing page num 104
# Parsing page num 105
# Parsing page num 106
# Parsing page num 107
# Parsing page num 108
# Parsing page num 109
# Parsing page num 110
# Parsing page num 111
# Parsing page num 112
# Parsing page num 113
# Parsing page num 114
# Parsing page num 115
# Parsing page num 116
# Parsing page num 117
# Parsing page num 118
# Parsing page num 119
# Parsing page num 120
# Parsing page num 121
# Parsing page num 122
# Parsing page num 123
# Parsing page num 124
# Parsing page num 125
# Parsing page num 126
# Parsing page num 127
# Parsing page num 128
# Parsing page num 129
# Parsing page num 130
# Parsing page num 131
# Parsing page num 132
# Parsing page num 133
# Parsing page num 134
# Parsing page num 135
# Parsing page num 136
# Parsing page num 137
# Parsing page num 138
# Parsing page num 139
# Parsing page num 140
# Parsing page num 141
# Parsing page num 142
# Parsing page num 143
# Parsing page num 144
# Parsing page num 145
# Parsing page num 146
# Parsing page num 147
# Parsing page num 148
# Parsing page num 149
# Parsing page num 150
# Parsing page num 151
# Parsing page num 152
# Parsing page num 153
# Parsing page num 154
# Parsing page num 155
# Parsing page num 156
# Parsing page num 157
# Parsing page num 158
# Parsing page num 159
# Parsing page num 160
# Parsing page num 161
# Parsing page num 162
# Parsing page num 163
# Parsing page num 164
# Parsing page num 165
# Parsing page num 166
# Parsing page num 167
# Parsing page num 168
# Parsing page num 169
# Parsing page num 170
# Parsing page num 171
# Parsing page num 172
# Parsing page num 173
# Parsing page num 174
# Parsing page num 175
# Parsing page num 176
# Parsing page num 177
# Parsing page num 178
# Parsing page num 179
# Parsing page num 180
# Parsing page num 181
# Parsing page num 182
# Parsing page num 183
# Parsing page num 184
# Parsing page num 185
# Parsing page num 186
# Parsing page num 187
# Parsing page num 188
# Parsing page num 189
# Parsing page num 190
# Parsing page num 191
# Parsing page num 192
# Parsing page num 193
# Parsing page num 194
# Parsing page num 195
# Parsing page num 196
# Parsing page num 197
# Parsing page num 198
# Parsing page num 199
# Parsing page num 200
# Parsing page num 201
# Parsing page num 202
# Parsing page num 203
# Parsing page num 204
# Parsing page num 205
# Parsing page num 206
# Parsing page num 207
# Parsing page num 208
# Parsing page num 209
# Parsing page num 210
# Parsing page num 211
# Parsing page num 212
# Parsing page num 213
# Parsing page num 214
# Parsing page num 215
# Parsing page num 216
# Parsing page num 217
# Parsing page num 218
# Parsing page num 219
# Parsing page num 220
# Parsing page num 221
# Parsing page num 222
# Parsing page num 223
# Parsing page num 224
# Parsing page num 225
# Parsing page num 226
# Parsing page num 227
# Parsing page num 228
# Parsing page num 229
# Parsing page num 230
# Parsing page num 231
# Parsing page num 232
# Parsing page num 233
# Parsing page num 234
# Parsing page num 235
# Parsing page num 236
# Parsing page num 237
# Parsing page num 238
# Parsing page num 239
# Parsing page num 240
# Parsing page num 241
# Parsing page num 242
# Parsing page num 243
# Parsing page num 244
# Parsing page num 245
# Parsing page num 246
# Parsing page num 247
# Parsing page num 248
# Parsing page num 249
# Parsing page num 250
# Parsing page num 251
# Parsing page num 252
# Parsing page num 253
# Parsing page num 254
# Parsing page num 255
# Parsing page num 256
# Parsing page num 257
# Parsing page num 258
# Parsing page num 259
# Parsing page num 260
# Parsing page num 261
# Parsing page num 262
# Parsing page num 263
# Parsing page num 264
# Parsing page num 265
# Parsing page num 266
# Parsing page num 267
# Parsing page num 268
# Parsing page num 269
# Parsing page num 270
# Parsing page num 271
# Parsing page num 272
# Parsing page num 273
# Parsing page num 274
# Parsing page num 275
# Parsing page num 276
# Parsing page num 277
# Parsing page num 278
# Parsing page num 279
# Parsing page num 280
# Parsing page num 281
# Parsing page num 282
# Parsing page num 283
# Parsing page num 284
# Parsing page num 285
# Parsing page num 286
# Parsing page num 287
# Parsing page num 288
# Parsing page num 289
# Parsing page num 290
# Parsing page num 291
# Parsing page num 292
# Parsing page num 293
# Parsing page num 294
# Parsing page num 295
# Parsing page num 296
# Parsing page num 297
# Parsing page num 298
# Parsing page num 299
# Parsing page num 300
# Parsing page num 301
# Parsing page num 302
# Parsing page num 303
# Parsing page num 304
# Parsing page num 305
# Parsing page num 306
# Parsing page num 307
# Parsing page num 308
# Parsing page num 309
# Parsing page num 310
# Parsing page num 311
# Parsing page num 312
# Parsing page num 313
# Parsing page num 314
# Parsing page num 315
# Parsing page num 316
# Parsing page num 317
# Parsing page num 318
# Parsing page num 319
# Parsing page num 320
# Parsing page num 321
# Parsing page num 322
# Parsing page num 323
# Parsing page num 324
# Parsing page num 325
# Parsing page num 326
# Parsing page num 327
# Parsing page num 328
# Parsing page num 329
# Parsing page num 330
# Parsing page num 331
# Parsing page num 332
# Parsing page num 333
# Parsing page num 334
# Parsing page num 335
# Parsing page num 336
# Parsing page num 337
# Parsing page num 338
# Parsing page num 339
# Parsing page num 340
# Parsing page num 341
# Parsing page num 342
# Parsing page num 343
# Parsing page num 344
# Parsing page num 345
# Parsing page num 346
# Parsing page num 347
# Parsing page num 348
# Parsing page num 349
# Parsing page num 350
# Parsing page num 351
# Parsing page num 352
# Parsing page num 353
# Parsing page num 354
# Parsing page num 355
# Parsing page num 356
# Parsing page num 357
# Parsing page num 358
# Parsing page num 359
# Parsing page num 360
# Parsing page num 361
# Parsing page num 362
# Parsing page num 363
# Parsing page num 364
# Parsing page num 365
# Parsing page num 366
# Parsing page num 367
# Parsing page num 368
# Parsing page num 369
# Parsing page num 370
# Parsing page num 371
# Parsing page num 372
# Parsing page num 373
# Parsing page num 374
# Parsing page num 375
# Parsing page num 376
# Parsing page num 377
# Parsing page num 378
# Parsing page num 379
# Parsing page num 380
# Parsing page num 381
# Parsing page num 382
# Parsing page num 383
# Parsing page num 384
# Parsing page num 385
# Parsing page num 386
# Parsing page num 387
# Parsing page num 388
# Parsing page num 389
# Parsing page num 390
# Parsing page num 391
# Parsing page num 392
# Parsing page num 393
# Parsing page num 394
# Parsing page num 395
# Parsing page num 396
# Parsing page num 397
# Parsing page num 398
# Parsing page num 399
# Parsing page num 400
# Parsing page num 401
# Parsing page num 402
# Parsing page num 403
# Parsing page num 404
# Parsing page num 405
# Parsing page num 406
# Parsing page num 407
# Parsing page num 408
# Parsing page num 409
# Parsing page num 410
# Parsing page num 411
# Parsing page num 412
# Parsing page num 413
# Parsing page num 414
# Parsing page num 415
# Parsing page num 416
# Parsing page num 417
# Parsing page num 418
# Parsing page num 419
# Parsing page num 420
# Parsing page num 421
# Parsing page num 422
# Parsing page num 423
# Parsing page num 424
# Parsing page num 425
# Parsing page num 426
# Parsing page num 427
# Parsing page num 428
# Parsing page num 429
# Parsing page num 430
# Parsing page num 431
# Parsing page num 432
# Parsing page num 433
# Parsing page num 434
# Parsing page num 435
# Parsing page num 436
# Parsing page num 437
# Parsing page num 438
# Parsing page num 439
# Parsing page num 440
# Parsing page num 441
# Parsing page num 442
# Parsing page num 443
# Parsing page num 444
# Parsing page num 445
# Parsing page num 446
# Parsing page num 447
# Parsing page num 448
# Parsing page num 449
# Parsing page num 450
# Parsing page num 451
# Parsing page num 452
# Parsing page num 453
# Parsing page num 454
# Parsing page num 455
# Parsing page num 456
# Parsing page num 457
# Parsing page num 458
# Parsing page num 459
# Parsing page num 460
# Parsing page num 461
# Parsing page num 462
# Parsing page num 463
# Parsing page num 464
# Parsing page num 465
# Parsing page num 466
# Parsing page num 467
# Parsing page num 468
# Parsing page num 469
# Parsing page num 470
# Parsing page num 471
# Parsing page num 472
# Parsing page num 473
# Parsing page num 474
# Parsing page num 475
# Parsing page num 476
# Parsing page num 477
# Parsing page num 478
# Parsing page num 479
# Parsing page num 480
# Parsing page num 481
# Parsing page num 482
# Parsing page num 483
# Parsing page num 484
# Parsing page num 485
# Parsing page num 486
# Parsing page num 487
# Parsing page num 488
# Parsing page num 489
# Parsing page num 490
# Parsing page num 491
# Parsing page num 492
# Parsing page num 493
# Parsing page num 494
# Parsing page num 495
# Parsing page num 496
# Parsing page num 497
# Parsing page num 498
# Parsing page num 499
# Parsing page num 500
# Parsing page num 501
# Parsing page num 502
# Parsing page num 503
# Parsing page num 504
# Parsing page num 505
# Parsing page num 506
# Parsing page num 507
# Parsing page num 508
# Parsing page num 509
# Parsing page num 510
# Parsing page num 511
# Parsing page num 512
# Parsing page num 513
# Parsing page num 514
# Parsing page num 515
# Parsing page num 516
# Parsing page num 517
# Parsing page num 518
# Parsing page num 519
# Parsing page num 520
# Parsing page num 521
# Parsing page num 522
# Parsing page num 523
# Parsing page num 524
# Parsing page num 525
# Parsing page num 526
# Parsing page num 527
# Parsing page num 528
# Parsing page num 529
# Parsing page num 530
# Parsing page num 531
# Parsing page num 532
# Parsing page num 533
# Parsing page num 534
# Parsing page num 535
# Parsing page num 536
# Parsing page num 537
# Parsing page num 538
# Parsing page num 539
# Parsing page num 540
# Parsing page num 541
# Parsing page num 542
# Parsing page num 543
# Parsing page num 544
# Parsing page num 545
# Parsing page num 546
# Parsing page num 547
# Parsing page num 548
# Parsing page num 549
# Parsing page num 550
# Parsing page num 551
# Parsing page num 552
# Parsing page num 553
# Parsing page num 554
# Parsing page num 555
# Parsing page num 556
# Parsing page num 557
# Parsing page num 558
# Parsing page num 559
# Parsing page num 560
# Parsing page num 561
# Parsing page num 562
# Parsing page num 563
# Parsing page num 564
# Parsing page num 565
# Parsing page num 566
# Parsing page num 567
# Parsing page num 568
# Parsing page num 569
# Parsing page num 570
# Parsing page num 571
# Parsing page num 572
# Parsing page num 573
# Parsing page num 574
# Parsing page num 575
# Parsing page num 576
# Parsing page num 577
# Parsing page num 578
# Parsing page num 579
# Parsing page num 580
# Parsing page num 581
# Parsing page num 582
# Parsing page num 583
# Parsing page num 584
# Parsing page num 585
# Parsing page num 586
# Parsing page num 587
# Parsing page num 588
# Parsing page num 589
# Parsing page num 590
# Parsing page num 591
# Parsing page num 592
# Parsing page num 593
# Parsing page num 594
# Parsing page num 595
# Parsing page num 596
# Parsing page num 597
# Parsing page num 598
# Parsing page num 599
# Parsing page num 600
# Parsing page num 601
# Parsing page num 602
# Parsing page num 603
# Parsing page num 604
# Parsing page num 605
# Parsing page num 606
# Parsing page num 607
# Parsing page num 608
# Parsing page num 609
# Parsing page num 610
# Parsing page num 611
# Parsing page num 612
# Parsing page num 613
# Parsing page num 614
# Parsing page num 615
# Parsing page num 616
# Parsing page num 617
# Parsing page num 618
# Parsing page num 619
# Parsing page num 620
# Parsing page num 621
# Parsing page num 622
# Parsing page num 623
# Parsing page num 624
# Parsing page num 625
# Parsing page num 626
# Parsing page num 627
# Parsing page num 628
# Parsing page num 629
# Parsing page num 630
# Parsing page num 631
# Parsing page num 632
# Parsing page num 633
# Parsing page num 634
# Parsing page num 635
# Parsing page num 636
# Parsing page num 637
# Parsing page num 638
# Parsing page num 639
# Parsing page num 640
# Parsing page num 641
# Parsing page num 642
# Parsing page num 643
# Parsing page num 644
# Parsing page num 645
# Parsing page num 646
# Parsing page num 647
# Parsing page num 648
# Parsing page num 649
# Parsing page num 650
# Parsing page num 651
# Parsing page num 652
# Parsing page num 653
# Parsing page num 654
# Parsing page num 655
# Parsing page num 656
# Parsing page num 657
# Parsing page num 658
# Parsing page num 659
# Parsing page num 660
# Parsing page num 661
# Parsing page num 662
# Parsing page num 663
# Parsing page num 664
# Parsing page num 665
# Parsing page num 666
# Parsing page num 667
# Parsing page num 668
# Parsing page num 669
# Parsing page num 670
# Parsing page num 671
# Parsing page num 672
# Parsing page num 673
# Parsing page num 674
# Parsing page num 675
# Parsing page num 676
# Parsing page num 677
# Parsing page num 678
# Parsing page num 679
# Parsing page num 680
# Parsing page num 681
# Parsing page num 682
# Parsing page num 683
# Parsing page num 684
# Parsing page num 685
# Parsing page num 686
# Parsing page num 687
# Parsing page num 688
# Parsing page num 689
# Parsing page num 690
# Parsing page num 691
# Parsing page num 692
# Parsing page num 693
# Parsing page num 694
# Parsing page num 695
# Parsing page num 696
# Parsing page num 697
# Parsing page num 698
# Parsing page num 699
# Parsing page num 700
# Parsing page num 701
# Parsing page num 702
# Parsing page num 703
# Parsing page num 704
# Parsing page num 705
# Parsing page num 706
# Parsing page num 707
# Parsing page num 708
# Parsing page num 709
# Parsing page num 710
# Parsing page num 711
# Parsing page num 712
# Parsing page num 713
# Parsing page num 714
# Parsing page num 715
# Parsing page num 716
# Parsing page num 717
# Parsing page num 718
# Parsing page num 719
# Parsing page num 720
# Parsing page num 721
# Parsing page num 722
# Parsing page num 723
# Parsing page num 724
# Parsing page num 725
# Parsing page num 726
# Parsing page num 727
# Parsing page num 728
# Parsing page num 729
# Parsing page num 730
# Parsing page num 731
# Parsing page num 732
# Parsing page num 733
# Parsing page num 734
# Parsing page num 735
# Parsing page num 736
# Parsing page num 737
# Parsing page num 738
# Parsing page num 739
# Parsing page num 740
# Parsing page num 741
# Parsing page num 742
# Parsing page num 743
# Parsing page num 744
# Parsing page num 745
# Parsing page num 746
# Parsing page num 747
# Parsing page num 748
# Parsing page num 749
# Parsing page num 750
# Parsing page num 751
# Parsing page num 752
# Parsing page num 753
# Parsing page num 754
# Parsing page num 755
# Parsing page num 756
# Parsing page num 757
# Parsing page num 758
# Parsing page num 759
# Parsing page num 760
# Parsing page num 761
# Parsing page num 762
# Parsing page num 763
# Parsing page num 764
# Parsing page num 765
# Parsing page num 766
# Parsing page num 767
# Parsing page num 768
# Parsing page num 769
# Parsing page num 770
# Parsing page num 771
# Parsing page num 772
# Parsing page num 773
# Parsing page num 774
# Parsing page num 775
# Parsing page num 776
# Parsing page num 777
# Parsing page num 778
# Parsing page num 779
# Parsing page num 780
# Parsing page num 781
# Parsing page num 782
# Parsing page num 783
# Parsing page num 784
# Parsing page num 785
# Parsing page num 786
# Parsing page num 787
# Parsing page num 788
# Parsing page num 789
# Parsing page num 790
# Parsing page num 791
# Parsing page num 792
# Parsing page num 793
# Parsing page num 794
# Parsing page num 795
# Parsing page num 796
# Parsing page num 797
# Parsing page num 798
# Parsing page num 799
# Parsing page num 800
# Parsing page num 801
# Parsing page num 802
# Parsing page num 803
# Parsing page num 804
# Parsing page num 805
# Parsing page num 806
# Parsing page num 807
# Parsing page num 808
# Parsing page num 809
# Parsing page num 810
# Parsing page num 811
# Parsing page num 812
# Parsing page num 813
# Parsing page num 814
# Parsing page num 815
# Parsing page num 816
# Parsing page num 817
# Parsing page num 818
# Parsing page num 819
# Parsing page num 820
# Parsing page num 821
# Parsing page num 822
# Parsing page num 823
# Parsing page num 824
# Parsing page num 825
# Parsing page num 826
# Parsing page num 827
# Parsing page num 828
# Parsing page num 829
# Parsing page num 830
# Parsing page num 831
# Parsing page num 832
# Parsing page num 833
# Parsing page num 834
# Parsing page num 835
# Parsing page num 836
# Parsing page num 837
# Parsing page num 838
# Parsing page num 839
# Parsing page num 840
# Parsing page num 841
# Parsing page num 842
# Parsing page num 843
# Parsing page num 844
# Parsing page num 845
# Parsing page num 846
# Parsing page num 847
# Parsing page num 848
# Parsing page num 849
# Parsing page num 850
# Parsing page num 851
# Parsing page num 852
# Parsing page num 853
# Parsing page num 854
# Parsing page num 855
# Parsing page num 856
# Parsing page num 857
# Parsing page num 858
# Parsing page num 859
# Parsing page num 860
# Parsing page num 861
# Parsing page num 862
# Parsing page num 863
# Parsing page num 864
# Parsing page num 865
# Parsing page num 866
# Parsing page num 867
# Parsing page num 868
# Parsing page num 869
# Parsing page num 870
# Parsing page num 871
# Parsing page num 872
# Parsing page num 873
# Parsing page num 874
# Parsing page num 875
# Parsing page num 876
# Parsing page num 877
# Parsing page num 878
# Parsing page num 879
# Parsing page num 880
# Parsing page num 881
# Parsing page num 882
# Parsing page num 883
# Parsing page num 884
# Parsing page num 885
# Parsing page num 886
# Parsing page num 887
# Parsing page num 888
# Parsing page num 889
# Parsing page num 890
# Parsing page num 891
# Parsing page num 892
# Parsing page num 893
# Parsing page num 894
# Parsing page num 895
# Parsing page num 896
# Parsing page num 897
# Parsing page num 898
# Parsing page num 899
# Parsing page num 900
# Parsing page num 901
# Parsing page num 902
# Parsing page num 903
# Parsing page num 904
# Parsing page num 905
# Parsing page num 906
# Parsing page num 907
# Parsing page num 908
# Parsing page num 909
# Parsing page num 910
# Parsing page num 911
# Parsing page num 912
# Parsing page num 913
# Parsing page num 914
# Parsing page num 915
# Parsing page num 916
# Parsing page num 917
# Parsing page num 918
# Parsing page num 919
# Parsing page num 920
# Parsing page num 921
# Parsing page num 922
# Parsing page num 923
# Parsing page num 924
# Parsing page num 925
# Parsing page num 926
# Parsing page num 927
# Parsing page num 928
# Parsing page num 929
# Parsing page num 930
# Parsing page num 931
# Parsing page num 932
# Parsing page num 933
# Parsing page num 934
# Parsing page num 935
# Parsing page num 936
# Parsing page num 937
# Parsing page num 938
# Parsing page num 939
# Parsing page num 940
# Parsing page num 941
# Parsing page num 942
# Parsing page num 943
# Parsing page num 944
# Parsing page num 945
# Parsing page num 946
# Parsing page num 947
# Parsing page num 948
# Parsing page num 949
# Parsing page num 950
# Parsing page num 951
# Parsing page num 952
# Parsing page num 953
# Parsing page num 954
# Parsing page num 955
# Parsing page num 956
# Parsing page num 957
# Parsing page num 958
# Parsing page num 959
# Parsing page num 960
# Parsing page num 961
# Parsing page num 962
# Parsing page num 963
# Parsing page num 964
# Parsing page num 965
# Parsing page num 966
# Parsing page num 967
# Parsing page num 968
# Parsing page num 969
# Parsing page num 970
# Parsing page num 971
# Parsing page num 972
# Parsing page num 973
# Parsing page num 974
# Parsing page num 975
# Parsing page num 976
# Parsing page num 977
# Parsing page num 978
# Parsing page num 979
# Parsing page num 980
# Parsing page num 981
# Parsing page num 982
# Parsing page num 983
# Parsing page num 984
# Parsing page num 985
# Parsing page num 986
# Parsing page num 987
# Parsing page num 988
# Parsing page num 989
# Parsing page num 990
# Parsing page num 991
# Parsing page num 992
# Parsing page num 993
# Parsing page num 994
# Parsing page num 995
# Parsing page num 996
# Parsing page num 997
# Parsing page num 998
# Parsing page num 999
# Parsing page num 1000
# Parsing page num 1001
# Parsing page num 1002
# Parsing page num 1003
# Parsing page num 1004
# Parsing page num 1005
# Parsing page num 1006
# Parsing page num 1007
# Parsing page num 1008
# Parsing page num 1009
# Parsing page num 1010
# Parsing page num 1011
# Parsing page num 1012
# Parsing page num 1013
# Parsing page num 1014
# Parsing page num 1015
# Parsing page num 1016
# Parsing page num 1017
# Parsing page num 1018
# Parsing page num 1019
# Parsing page num 1020
# Parsing page num 1021
# Parsing page num 1022
# Parsing page num 1023
# Parsing page num 1024
# Parsing page num 1025
# Parsing page num 1026
# Parsing page num 1027
# Parsing page num 1028
# Parsing page num 1029
# Parsing page num 1030
# Parsing page num 1031
# Parsing page num 1032
# Parsing page num 1033
# Parsing page num 1034
# Parsing page num 1035
# Parsing page num 1036
# Parsing page num 1037
# Parsing page num 1038
# Parsing page num 1039
# Parsing page num 1040
# Parsing page num 1041
# Parsing page num 1042
# Parsing page num 1043
# Parsing page num 1044
# Parsing page num 1045
# Parsing page num 1046
# Parsing page num 1047
# Parsing page num 1048
# Parsing page num 1049
# Parsing page num 1050
# Parsing page num 1051
# Parsing page num 1052
# Parsing page num 1053
# Parsing page num 1054
# Parsing page num 1055
# Parsing page num 1056
# Parsing page num 1057
# Parsing page num 1058
# Parsing page num 1059
# Parsing page num 1060
# Parsing page num 1061
# Parsing page num 1062
# Parsing page num 1063
# Parsing page num 1064
# Parsing page num 1065
# Parsing page num 1066
# Parsing page num 1067
# Parsing page num 1068
# Parsing page num 1069
# Parsing page num 1070
# Parsing page num 1071
# Parsing page num 1072
# Parsing page num 1073
# Parsing page num 1074
# Parsing page num 1075
# Parsing page num 1076
# Parsing page num 1077
# Parsing page num 1078
# Parsing page num 1079
# Parsing page num 1080
# Parsing page num 1081
# Parsing page num 1082
# Parsing page num 1083
# Parsing page num 1084
# Parsing page num 1085
# Parsing page num 1086
# Parsing page num 1087
# Parsing page num 1088
# Parsing page num 1089
# Parsing page num 1090
# Parsing page num 1091
# Parsing page num 1092
# Parsing page num 1093
# Parsing page num 1094
# Parsing page num 1095
# Parsing page num 1096
# Parsing page num 1097
# Parsing page num 1098
# Parsing page num 1099
# Parsing page num 1100
# Parsing page num 1101
# Parsing page num 1102
# Parsing page num 1103
# Parsing page num 1104
# Parsing page num 1105
# Parsing page num 1106
# Parsing page num 1107
# Parsing page num 1108
# Parsing page num 1109
# Parsing page num 1110
# Parsing page num 1111
# Parsing page num 1112
# Parsing page num 1113
# Parsing page num 1114
# Parsing page num 1115
# Parsing page num 1116
# Parsing page num 1117
# Parsing page num 1118
# Parsing page num 1119
# Parsing page num 1120
# Parsing page num 1121
# Parsing page num 1122
# Parsing page num 1123
# Parsing page num 1124
# Parsing page num 1125
# Parsing page num 1126
# Parsing page num 1127
# Parsing page num 1128
# Parsing page num 1129
# Parsing page num 1130
# Parsing page num 1131
# Parsing page num 1132
# Parsing page num 1133
# Parsing page num 1134
# Parsing page num 1135
# Parsing page num 1136
# Parsing page num 1137
# Parsing page num 1138
# Parsing page num 1139
# Parsing page num 1140
# Parsing page num 1141
# Parsing page num 1142
# Parsing page num 1143
# Parsing page num 1144
# Parsing page num 1145
# Parsing page num 1146
# Parsing page num 1147
# Parsing page num 1148
# Parsing page num 1149
# Parsing page num 1150
# Parsing page num 1151
# Parsing page num 1152
# Parsing page num 1153
# Parsing page num 1154
# Parsing page num 1155
# Parsing page num 1156
# Parsing page num 1157
# Parsing page num 1158
# Parsing page num 1159
# Parsing page num 1160
# Parsing page num 1161
# Parsing page num 1162
# Parsing page num 1163
# Parsing page num 1164
# Parsing page num 1165
# Parsing page num 1166
# Parsing page num 1167
# Parsing page num 1168
# Parsing page num 1169
# Parsing page num 1170
# Parsing page num 1171
# Parsing page num 1172
# Parsing page num 1173
# Parsing page num 1174
# Parsing page num 1175
# Parsing page num 1176
# Parsing page num 1177
# Parsing page num 1178
# Parsing page num 1179
# Parsing page num 1180
# Parsing page num 1181
# Parsing page num 1182
# Parsing page num 1183
# Parsing page num 1184
# Parsing page num 1185
# Parsing page num 1186
# Parsing page num 1187
# Parsing page num 1188
# Parsing page num 1189
# Parsing page num 1190
# Parsing page num 1191
# Parsing page num 1192
# Parsing page num 1193
# Parsing page num 1194
# Parsing page num 1195
# Parsing page num 1196
# Parsing page num 1197
# Parsing page num 1198
# Parsing page num 1199
# Parsing page num 1200
# Parsing page num 1201
# Parsing page num 1202
# Parsing page num 1203
# Parsing page num 1204
# Parsing page num 1205
# Parsing page num 1206
# Parsing page num 1207
# Parsing page num 1208
# Parsing page num 1209
# Parsing page num 1210
# Parsing page num 1211
# Parsing page num 1212
# Parsing page num 1213
# Parsing page num 1214
# Parsing page num 1215
# Parsing page num 1216
# Parsing page num 1217
# Parsing page num 1218
# Parsing page num 1219
# Parsing page num 1220
# Parsing page num 1221
# Parsing page num 1222
# Parsing page num 1223
# Parsing page num 1224
# Parsing page num 1225
# Parsing page num 1226
# Parsing page num 1227
# Parsing page num 1228
# Parsing page num 1229
# Parsing page num 1230
# Parsing page num 1231
# Parsing page num 1232
# Parsing page num 1233
# Parsing page num 1234
# Parsing page num 1235
# Parsing page num 1236
# Parsing page num 1237
# Parsing page num 1238
# Parsing page num 1239
# Parsing page num 1240
# Parsing page num 1241
# Parsing page num 1242
# Parsing page num 1243
# Parsing page num 1244
# Parsing page num 1245
# Parsing page num 1246
# Parsing page num 1247
# Parsing page num 1248
# Parsing page num 1249
# Parsing page num 1250
# Parsing page num 1251
# Parsing page num 1252
# Parsing page num 1253
# Parsing page num 1254
# Parsing page num 1255
# Parsing page num 1256
# Parsing page num 1257
# Parsing page num 1258
# Parsing page num 1259
# Parsing page num 1260
# Parsing page num 1261
# Parsing page num 1262
# Parsing page num 1263
# Parsing page num 1264
# Parsing page num 1265
# Parsing page num 1266
# Parsing page num 1267
# Parsing page num 1268
# Parsing page num 1269
# Parsing page num 1270
# Parsing page num 1271
# Parsing page num 1272
# Parsing page num 1273
# Parsing page num 1274
# Parsing page num 1275
# Parsing page num 1276
# Parsing page num 1277
# Parsing page num 1278
# Parsing page num 1279
# Parsing page num 1280
# Parsing page num 1281
# Parsing page num 1282
# Parsing page num 1283
# Parsing page num 1284
# Parsing page num 1285
# Parsing page num 1286
# Parsing page num 1287
# Parsing page num 1288
# Parsing page num 1289
# Parsing page num 1290
# Parsing page num 1291
# Parsing page num 1292
# Parsing page num 1293
# Parsing page num 1294
# Parsing page num 1295
# Parsing page num 1296
# Parsing page num 1297
# Parsing page num 1298
# Parsing page num 1299
# Parsing page num 1300
# Parsing page num 1301
# Parsing page num 1302
# Parsing page num 1303
# Parsing page num 1304
# Parsing page num 1305
# Parsing page num 1306
# Parsing page num 1307
# Parsing page num 1308
# Parsing page num 1309
# Parsing page num 1310
# Parsing page num 1311
# Parsing page num 1312
# Parsing page num 1313
# Parsing page num 1314
# Parsing page num 1315
# Parsing page num 1316
# Parsing page num 1317
# Parsing page num 1318
# Parsing page num 1319
# Parsing page num 1320
# Parsing page num 1321
# Parsing page num 1322
# Parsing page num 1323
# Parsing page num 1324
# Parsing page num 1325
# Parsing page num 1326
# Parsing page num 1327
# Parsing page num 1328
# Parsing page num 1329
# Parsing page num 1330
# Parsing page num 1331
# Parsing page num 1332
# Parsing page num 1333
# Parsing page num 1334
# Parsing page num 1335
# Parsing page num 1336
# Parsing page num 1337
# Parsing page num 1338
# Parsing page num 1339
# Parsing page num 1340
# Parsing page num 1341
# Parsing page num 1342
# Parsing page num 1343
# Parsing page num 1344
# Parsing page num 1345
# Parsing page num 1346
# Parsing page num 1347
# Parsing page num 1348
# Parsing page num 1349
# Parsing page num 1350
# Parsing page num 1351
# Parsing page num 1352
# Parsing page num 1353
# Parsing page num 1354
# Parsing page num 1355
# Parsing page num 1356
# Parsing page num 1357
# Parsing page num 1358
# Parsing page num 1359
# Parsing page num 1360
# Parsing page num 1361
# Parsing page num 1362
# Parsing page num 1363
# Parsing page num 1364
# Parsing page num 1365
# Parsing page num 1366
# Parsing page num 1367
# Parsing page num 1368
# Parsing page num 1369
# Parsing page num 1370
# Parsing page num 1371
# Parsing page num 1372
# Parsing page num 1373
# Parsing page num 1374
# Parsing page num 1375
# Parsing page num 1376
# Parsing page num 1377
# Parsing page num 1378
# Parsing page num 1379
# Parsing page num 1380
# Parsing page num 1381
# Parsing page num 1382
# Parsing page num 1383
# Parsing page num 1384
# Parsing page num 1385
# Parsing page num 1386
# Parsing page num 1387
# Parsing page num 1388
# Parsing page num 1389
# Parsing page num 1390
# Parsing page num 1391
# Parsing page num 1392
# Parsing page num 1393
# Parsing page num 1394
# Parsing page num 1395
# Parsing page num 1396
# Parsing page num 1397
# Parsing page num 1398
# Parsing page num 1399
# Parsing page num 1400
# Parsing page num 1401
# Parsing page num 1402
# Parsing page num 1403
# Parsing page num 1404
# Parsing page num 1405
# Parsing page num 1406
# Parsing page num 1407
# Parsing page num 1408
# Parsing page num 1409
# Parsing page num 1410
# Parsing page num 1411
# Parsing page num 1412
# Parsing page num 1413
# Parsing page num 1414
# Parsing page num 1415
# Parsing page num 1416
# Parsing page num 1417
# Parsing page num 1418
# Parsing page num 1419
# Parsing page num 1420
# Parsing page num 1421
# Parsing page num 1422
# Parsing page num 1423
# Parsing page num 1424
# Parsing page num 1425
# Parsing page num 1426
# Parsing page num 1427
# Parsing page num 1428
# Parsing page num 1429
# Parsing page num 1430
# Parsing page num 1431
# Parsing page num 1432
# Parsing page num 1433
# Parsing page num 1434
# Parsing page num 1435
# Parsing page num 1436
# Parsing page num 1437
# Parsing page num 1438
# Parsing page num 1439
# Parsing page num 1440
# Parsing page num 1441
# Parsing page num 1442
# Parsing page num 1443
# Parsing page num 1444
# Parsing page num 1445
# Parsing page num 1446
# Parsing page num 1447
# Parsing page num 1448
# Parsing page num 1449
# Parsing page num 1450
# Parsing page num 1451
# Parsing page num 1452
# Parsing page num 1453
# Parsing page num 1454
# Parsing page num 1455
# Parsing page num 1456
# Parsing page num 1457
# Parsing page num 1458
# Parsing page num 1459
# Parsing page num 1460
# Parsing page num 1461
# Parsing page num 1462
# Parsing page num 1463
# Parsing page num 1464
# Parsing page num 1465
# Parsing page num 1466
# Parsing page num 1467
# Parsing page num 1468
# Parsing page num 1469
# Parsing page num 1470
# Parsing page num 1471
# Parsing page num 1472
# Parsing page num 1473
# Parsing page num 1474
# Parsing page num 1475
# Parsing page num 1476
# Parsing page num 1477
# Parsing page num 1478
# Parsing page num 1479
# Parsing page num 1480
# Parsing page num 1481
# Parsing page num 1482
# Parsing page num 1483
# Parsing page num 1484
# Parsing page num 1485
# Parsing page num 1486
# Parsing page num 1487
# Parsing page num 1488
# Parsing page num 1489
# Parsing page num 1490
# Parsing page num 1491
# Parsing page num 1492
# Parsing page num 1493
# Parsing page num 1494
# Parsing page num 1495
# Parsing page num 1496
# Parsing page num 1497
# Parsing page num 1498
# Parsing page num 1499
# Parsing page num 1500
# Parsing page num 1501
# Parsing page num 1502
# Parsing page num 1503
# Parsing page num 1504
# Parsing page num 1505
# Parsing page num 1506
# Parsing page num 1507
# Parsing page num 1508
# Parsing page num 1509
# Parsing page num 1510
# Parsing page num 1511
# Parsing page num 1512
# Parsing page num 1513
# Parsing page num 1514
# Parsing page num 1515
# Parsing page num 1516
# Parsing page num 1517
# Parsing page num 1518
# Parsing page num 1519
# Parsing page num 1520
# Parsing page num 1521
# Parsing page num 1522
# Parsing page num 1523
# Parsing page num 1524
# Parsing page num 1525
# Parsing page num 1526
# Parsing page num 1527
# Parsing page num 1528
# Parsing page num 1529
# Parsing page num 1530
# Parsing page num 1531
# Parsing page num 1532
# Parsing page num 1533
# Parsing page num 1534
# Parsing page num 1535
# Parsing page num 1536
# Parsing page num 1537
# Parsing page num 1538
# Parsing page num 1539
# Parsing page num 1540
# Parsing page num 1541
# Parsing page num 1542
# Parsing page num 1543
# Parsing page num 1544
# Parsing page num 1545
# Parsing page num 1546
# Parsing page num 1547
# Parsing page num 1548
# Parsing page num 1549
# Parsing page num 1550
# Parsing page num 1551
# Parsing page num 1552
# Parsing page num 1553
# Parsing page num 1554
# Parsing page num 1555
# Parsing page num 1556
# Parsing page num 1557
# Parsing page num 1558
# Parsing page num 1559
# Parsing page num 1560
# Parsing page num 1561
# Parsing page num 1562
# Parsing page num 1563
# Parsing page num 1564
# Parsing page num 1565
# Parsing page num 1566
# Parsing page num 1567
# Parsing page num 1568
# Parsing page num 1569
# Parsing page num 1570
# Parsing page num 1571
# Parsing page num 1572
# Parsing page num 1573
# Parsing page num 1574
# Parsing page num 1575
# Parsing page num 1576
# Parsing page num 1577
# Parsing page num 1578
# Parsing page num 1579
# Parsing page num 1580
# Parsing page num 1581
# Parsing page num 1582
# Parsing page num 1583
# Parsing page num 1584
# Parsing page num 1585
# Parsing page num 1586
# Parsing page num 1587
# Parsing page num 1588
# Parsing page num 1589
# Parsing page num 1590
# Parsing page num 1591
# Parsing page num 1592
# Parsing page num 1593
# Parsing page num 1594
# Parsing page num 1595
# Parsing page num 1596
# Parsing page num 1597
# Parsing page num 1598
# Parsing page num 1599
# Parsing page num 1600
# Parsing page num 1601
# Parsing page num 1602
# Parsing page num 1603
# Parsing page num 1604
# Parsing page num 1605
# Parsing page num 1606
# Parsing page num 1607
# Parsing page num 1608
# Parsing page num 1609
# Parsing page num 1610
# Parsing page num 1611
# Parsing page num 1612
# Parsing page num 1613
# Parsing page num 1614
# Parsing page num 1615
# Parsing page num 1616
# Parsing page num 1617
# Parsing page num 1618
# Parsing page num 1619
# Parsing page num 1620
# Parsing page num 1621
# Parsing page num 1622
# Parsing page num 1623
# Parsing page num 1624
# Parsing page num 1625
# Parsing page num 1626
# Parsing page num 1627
# Parsing page num 1628
# Parsing page num 1629
# Parsing page num 1630
# Parsing page num 1631
# Parsing page num 1632
# Parsing page num 1633
# Parsing page num 1634
# Parsing page num 1635
# Parsing page num 1636
# Parsing page num 1637
# Parsing page num 1638
# Parsing page num 1639
# Parsing page num 1640
# Parsing page num 1641
# Parsing page num 1642
# Parsing page num 1643
# Parsing page num 1644
# Parsing page num 1645
# Parsing page num 1646
# Parsing page num 1647
# Parsing page num 1648
# Parsing page num 1649
# Parsing page num 1650
# Parsing page num 1651
# Parsing page num 1652
# Parsing page num 1653
# Parsing page num 1654
# Parsing page num 1655
# Parsing page num 1656
# Parsing page num 1657
# Parsing page num 1658
# Parsing page num 1659
# Parsing page num 1660
# Parsing page num 1661
# Parsing page num 1662
# Parsing page num 1663
# Parsing page num 1664
# Parsing page num 1665
# Parsing page num 1666
# Parsing page num 1667
# Parsing page num 1668
# Parsing page num 1669
# Parsing page num 1670
# Parsing page num 1671
# Parsing page num 1672
# Parsing page num 1673
# Parsing page num 1674
# Parsing page num 1675
# Parsing page num 1676
# Parsing page num 1677
# Parsing page num 1678
# Parsing page num 1679
# Parsing page num 1680
# Parsing page num 1681
# Parsing page num 1682
# Parsing page num 1683
# Parsing page num 1684
# Parsing page num 1685
# Parsing page num 1686
# Parsing page num 1687
# Parsing page num 1688
# Parsing page num 1689
# Parsing page num 1690
# Parsing page num 1691
# Parsing page num 1692
# Parsing page num 1693
# Parsing page num 1694
# Parsing page num 1695
# Parsing page num 1696
# Parsing page num 1697
# Parsing page num 1698
# Parsing page num 1699
# Parsing page num 1700
# Parsing page num 1701
# Parsing page num 1702
# Parsing page num 1703
# Parsing page num 1704
# Parsing page num 1705
# Parsing page num 1706
# Parsing page num 1707
# Parsing page num 1708
# Parsing page num 1709
# Parsing page num 1710
# Parsing page num 1711
# Parsing page num 1712
# Parsing page num 1713
# Parsing page num 1714
# Parsing page num 1715
# Parsing page num 1716
# Parsing page num 1717
# Parsing page num 1718
# Parsing page num 1719
# Parsing page num 1720
# Parsing page num 1721
# Parsing page num 1722
# Parsing page num 1723
# Parsing page num 1724
# Parsing page num 1725
# Parsing page num 1726
# Parsing page num 1727
# Parsing page num 1728
# Parsing page num 1729
# Parsing page num 1730
# Parsing page num 1731
# Parsing page num 1732
# Parsing page num 1733
# Parsing page num 1734
# Parsing page num 1735
# Parsing page num 1736
# Parsing page num 1737
# Parsing page num 1738
# Parsing page num 1739
# Parsing page num 1740
# Parsing page num 1741
# Parsing page num 1742
# Parsing page num 1743
# Parsing page num 1744
# Parsing page num 1745
# Parsing page num 1746
# Parsing page num 1747
# Parsing page num 1748
# Parsing page num 1749
# Parsing page num 1750
# Parsing page num 1751
# Parsing page num 1752
# Parsing page num 1753
# Parsing page num 1754
# Parsing page num 1755
# Parsing page num 1756
# Parsing page num 1757
# Parsing page num 1758
# Parsing page num 1759
# Parsing page num 1760
# Parsing page num 1761
# Parsing page num 1762
# Parsing page num 1763
# Parsing page num 1764
# Parsing page num 1765
# Parsing page num 1766
# Parsing page num 1767
# Parsing page num 1768
# Parsing page num 1769
# Parsing page num 1770
# Parsing page num 1771
# Parsing page num 1772
# Parsing page num 1773
# Parsing page num 1774
# Parsing page num 1775
# Parsing page num 1776
# Parsing page num 1777
# Parsing page num 1778
# Parsing page num 1779
# Parsing page num 1780
# Parsing page num 1781
# Parsing page num 1782
# Parsing page num 1783
# Parsing page num 1784
# Parsing page num 1785
# Parsing page num 1786
# Parsing page num 1787
# Parsing page num 1788
# Parsing page num 1789
# Parsing page num 1790
# Parsing page num 1791
# Parsing page num 1792
# Parsing page num 1793
# Parsing page num 1794
# Parsing page num 1795
# Parsing page num 1796
# Parsing page num 1797
# Parsing page num 1798
# Parsing page num 1799
# Parsing page num 1800
# Parsing page num 1801
# Parsing page num 1802
# Parsing page num 1803
# Parsing page num 1804
# Parsing page num 1805
# Parsing page num 1806
# Parsing page num 1807
# Parsing page num 1808
# Parsing page num 1809
# Parsing page num 1810
# Parsing page num 1811
# Parsing page num 1812
# Parsing page num 1813
# Parsing page num 1814
# Parsing page num 1815
# Parsing page num 1816
# Parsing page num 1817
# Parsing page num 1818
# Parsing page num 1819
# Parsing page num 1820
# Parsing page num 1821
# Parsing page num 1822
# Parsing page num 1823
# Parsing page num 1824
# Parsing page num 1825
# Parsing page num 1826
# Parsing page num 1827
# Parsing page num 1828
# Parsing page num 1829
# Parsing page num 1830
# Parsing page num 1831
# Parsing page num 1832
# Parsing page num 1833
# Parsing page num 1834
# Parsing page num 1835
# Parsing page num 1836
# Parsing page num 1837
# Parsing page num 1838
# Parsing page num 1839
# Parsing page num 1840
# Parsing page num 1841
# Parsing page num 1842
# Parsing page num 1843
# Parsing page num 1844
# Parsing page num 1845
# Parsing page num 1846
# Parsing page num 1847
# Parsing page num 1848
# Parsing page num 1849
# Parsing page num 1850
# Parsing page num 1851
# Parsing page num 1852
# Parsing page num 1853
# Parsing page num 1854
# Parsing page num 1855
# Parsing page num 1856
# Parsing page num 1857
# Parsing page num 1858
# Parsing page num 1859
# Parsing page num 1860
# Parsing page num 1861
# Parsing page num 1862
# Parsing page num 1863
# Parsing page num 1864
# Parsing page num 1865
# Parsing page num 1866
# Parsing page num 1867
# Parsing page num 1868
# Parsing page num 1869
# Parsing page num 1870
# Parsing page num 1871
# Parsing page num 1872
# Parsing page num 1873
# Parsing page num 1874
# Parsing page num 1875
# Parsing page num 1876
# Parsing page num 1877
# Parsing page num 1878
# Parsing page num 1879
# Parsing page num 1880
# Parsing page num 1881
# Parsing page num 1882
# Parsing page num 1883
# Parsing page num 1884
# Parsing page num 1885
# Parsing page num 1886
# Parsing page num 1887
# Parsing page num 1888
# Parsing page num 1889
# Parsing page num 1890
# Parsing page num 1891
# Parsing page num 1892
# Parsing page num 1893
# Parsing page num 1894
# Parsing page num 1895
# Parsing page num 1896
# Parsing page num 1897
# Parsing page num 1898
# Parsing page num 1899
# Parsing page num 1900
# Parsing page num 1901
# Parsing page num 1902
# Parsing page num 1903
# Parsing page num 1904
# Parsing page num 1905
# Parsing page num 1906
# Parsing page num 1907
# Parsing page num 1908
# Parsing page num 1909
# Parsing page num 1910
# Parsing page num 1911
# Parsing page num 1912
# Parsing page num 1913
# Parsing page num 1914
# Parsing page num 1915
# Parsing page num 1916
# Parsing page num 1917
# Parsing page num 1918
# Parsing page num 1919
# Parsing page num 1920
# Parsing page num 1921
# Parsing page num 1922
# Parsing page num 1923
# Parsing page num 1924
# Parsing page num 1925
# Parsing page num 1926
# Parsing page num 1927
# Parsing page num 1928
# Parsing page num 1929
# Parsing page num 1930
# Parsing page num 1931
# Parsing page num 1932
# Parsing page num 1933
# Parsing page num 1934
# Parsing page num 1935
# Parsing page num 1936
# Parsing page num 1937
# Parsing page num 1938
# Parsing page num 1939
# Parsing page num 1940
# Parsing page num 1941
# Parsing page num 1942
# Parsing page num 1943
# Parsing page num 1944
# Parsing page num 1945
# Parsing page num 1946
# Parsing page num 1947
# Parsing page num 1948
# Parsing page num 1949
# Parsing page num 1950
# Parsing page num 1951
# Parsing page num 1952
# Parsing page num 1953
# Parsing page num 1954
# Parsing page num 1955
# Parsing page num 1956
# Parsing page num 1957
# Parsing page num 1958
# Parsing page num 1959
# Parsing page num 1960
# Parsing page num 1961
# Parsing page num 1962
# Parsing page num 1963
# Parsing page num 1964
# Parsing page num 1965
# Parsing page num 1966
# Parsing page num 1967
# Parsing page num 1968
# Parsing page num 1969
# Parsing page num 1970
# Parsing page num 1971
# Parsing page num 1972
# Parsing page num 1973
# Parsing page num 1974
# Parsing page num 1975
# Parsing page num 1976
# Parsing page num 1977
# Parsing page num 1978
# Parsing page num 1979
# Parsing page num 1980
# Parsing page num 1981
# Parsing page num 1982
# Parsing page num 1983
# Parsing page num 1984
# Parsing page num 1985
# Parsing page num 1986
# Parsing page num 1987
# Parsing page num 1988
# Parsing page num 1989
# Parsing page num 1990
# Parsing page num 1991
# Parsing page num 1992
# Parsing page num 1993
# Parsing page num 1994
# Parsing page num 1995
# Parsing page num 1996
# Parsing page num 1997
# Parsing page num 1998
# Parsing page num 1999
# Parsing page num 2000
# Parsing page num 2001
# Parsing page num 2002
# Parsing page num 2003
# Parsing page num 2004
# Parsing page num 2005
# Parsing page num 2006
# Parsing page num 2007
# Parsing page num 2008
# Parsing page num 2009
# Parsing page num 2010
# Parsing page num 2011
# Parsing page num 2012
# Parsing page num 2013
# Parsing page num 2014
# Parsing page num 2015
# Parsing page num 2016
# Parsing page num 2017
# Parsing page num 2018
# Parsing page num 2019
# Parsing page num 2020
# Parsing page num 2021
# Parsing page num 2022
# Parsing page num 2023
# Parsing page num 2024
# Parsing page num 2025
# Parsing page num 2026
# Parsing page num 2027
# Parsing page num 2028
# Parsing page num 2029
# Parsing page num 2030
# Parsing page num 2031
# Parsing page num 2032
# Parsing page num 2033
# Parsing page num 2034
# Parsing page num 2035
# Parsing page num 2036
# Parsing page num 2037
# Parsing page num 2038
# Parsing page num 2039
# Parsing page num 2040
# Parsing page num 2041
# Parsing page num 2042
# Parsing page num 2043
# Parsing page num 2044
# Parsing page num 2045
# Parsing page num 2046
# Parsing page num 2047
# Parsing page num 2048
# Parsing page num 2049
# Parsing page num 2050
# Parsing page num 2051
# Parsing page num 2052
# Parsing page num 2053
# Parsing page num 2054
# Parsing page num 2055
# Parsing page num 2056
# Parsing page num 2057
# Parsing page num 2058
# Parsing page num 2059
# Parsing page num 2060
# Parsing page num 2061
# Parsing page num 2062
# Parsing page num 2063
# Parsing page num 2064
# Parsing page num 2065
# Parsing page num 2066
# Parsing page num 2067
# Parsing page num 2068
# Parsing page num 2069
# Parsing page num 2070
# Parsing page num 2071
# Parsing page num 2072
# Parsing page num 2073
# Parsing page num 2074
# Parsing page num 2075
# Parsing page num 2076
# Parsing page num 2077
# Parsing page num 2078
# Parsing page num 2079
# Parsing page num 2080
# Parsing page num 2081
# Parsing page num 2082
# Parsing page num 2083
# Parsing page num 2084
# Parsing page num 2085
# Parsing page num 2086
# Parsing page num 2087
# Parsing page num 2088
# Parsing page num 2089
# Parsing page num 2090
# Parsing page num 2091
# Parsing page num 2092
# Parsing page num 2093
# Parsing page num 2094
# Parsing page num 2095
# Parsing page num 2096
# Parsing page num 2097
# Parsing page num 2098
# Parsing page num 2099
# Parsing page num 2100
# Parsing page num 2101
# Parsing page num 2102
# Parsing page num 2103
# Parsing page num 2104
# Parsing page num 2105
# Parsing page num 2106
# Parsing page num 2107
# Parsing page num 2108
# Parsing page num 2109
# Parsing page num 2110
# Parsing page num 2111
# Parsing page num 2112
# Parsing page num 2113
# Parsing page num 2114
# Parsing page num 2115
# Parsing page num 2116
# Parsing page num 2117
# Parsing page num 2118
# Parsing page num 2119
# Parsing page num 2120
# Parsing page num 2121
# Parsing page num 2122
# Parsing page num 2123
# Parsing page num 2124
# Parsing page num 2125
# Parsing page num 2126
# Parsing page num 2127
# Parsing page num 2128
# Parsing page num 2129
# Parsing page num 2130
# Parsing page num 2131
# Parsing page num 2132
# Parsing page num 2133
# Parsing page num 2134
# Parsing page num 2135
# Parsing page num 2136
# Parsing page num 2137
# Parsing page num 2138
# Parsing page num 2139
# Parsing page num 2140
# Parsing page num 2141
# Parsing page num 2142
# Parsing page num 2143
# Parsing page num 2144
# Parsing page num 2145
# Parsing page num 2146
# Parsing page num 2147
# Parsing page num 2148
# Parsing page num 2149
# Parsing page num 2150
# Parsing page num 2151
# Parsing page num 2152
# Parsing page num 2153
# Parsing page num 2154
# Parsing page num 2155
# Parsing page num 2156
# Parsing page num 2157
# Parsing page num 2158
# Parsing page num 2159
# Parsing page num 2160
# Parsing page num 2161
# Parsing page num 2162
# Parsing page num 2163
# Parsing page num 2164
# Parsing page num 2165
# Parsing page num 2166
# Parsing page num 2167
# Parsing page num 2168
# Parsing page num 2169
# Parsing page num 2170
# Parsing page num 2171
# Parsing page num 2172
# Parsing page num 2173
# Parsing page num 2174
# Parsing page num 2175
# Parsing page num 2176
# Parsing page num 2177
# Parsing page num 2178
# Parsing page num 2179
# Parsing page num 2180
# Parsing page num 2181
# Parsing page num 2182
# Parsing page num 2183
# Parsing page num 2184
# Parsing page num 2185
# Parsing page num 2186
# Parsing page num 2187
# Parsing page num 2188
# Parsing page num 2189
# Parsing page num 2190
# Parsing page num 2191
# Parsing page num 2192
# Parsing page num 2193
# Parsing page num 2194
# Parsing page num 2195
# Parsing page num 2196
# Parsing page num 2197
# Parsing page num 2198
# Parsing page num 2199
# Parsing page num 2200
# Parsing page num 2201
# Parsing page num 2202
# Parsing page num 2203
# Parsing page num 2204
# Parsing page num 2205
# Parsing page num 2206
# Parsing page num 2207
# Parsing page num 2208
# Parsing page num 2209
# Parsing page num 2210
# Parsing page num 2211
# Parsing page num 2212
# Parsing page num 2213
# Parsing page num 2214
# Parsing page num 2215
# Parsing page num 2216
# Parsing page num 2217
# Parsing page num 2218
# Parsing page num 2219
# Parsing page num 2220
# Parsing page num 2221
# Parsing page num 2222
# Parsing page num 2223
# Parsing page num 2224
# Parsing page num 2225
# Parsing page num 2226
# Parsing page num 2227
# Parsing page num 2228
# Parsing page num 2229
# Parsing page num 2230
# Parsing page num 2231
# Parsing page num 2232
# ...
# Parsing page num 2938
# Parsing page num 2939
# Parsing page num 2940
# Parsing page num 2941
# Parsing page num 2942
# Parsing page num 2943
# Parsing page num 2944
# Parsing page num 2945
# Parsing page num 2946
# Parsing page num 2947
# Parsing page num 2948
# Parsing page num 2949
# Parsing page num 2950
# Parsing page num 2951
# Parsing page num 2952
# Parsing page num 2953
# Parsing page num 2954
# Parsing page num 2955
# Parsing page num 2956
# Parsing page num 2957
# Parsing page num 2958
# Parsing page num 2959
# Parsing page num 2960
# Parsing page num 2961
# Parsing page num 2962
# Parsing page num 2963
# Parsing page num 2964
# Parsing page num 2965
# Parsing page num 2966
# Parsing page num 2967
# Parsing page num 2968
# Parsing page num 2969
# Parsing page num 2970
# Parsing page num 2971
# Parsing page num 2972
# Parsing page num 2973
# Parsing page num 2974
# Parsing page num 2975
# Parsing page num 2976
# Parsing page num 2977
# Parsing page num 2978
# Parsing page num 2979
# Parsing page num 2980
# Parsing page num 2981
# Parsing page num 2982
# Parsing page num 2983
# Parsing page num 2984
# Parsing page num 2985
# Parsing page num 2986
# Parsing page num 2987
# Parsing page num 2988
# Parsing page num 2989
# Parsing page num 2990
# Parsing page num 2991
# Parsing page num 2992
# Parsing page num 2993
# Parsing page num 2994
# Parsing page num 2995
# Parsing page num 2996
# Parsing page num 2997
# Parsing page num 2998
# Parsing page num 2999
# Parsing page num 3000
# Parsing page num 3001
# Parsing page num 3002
# Parsing page num 3003
# Parsing page num 3004
# Parsing page num 3005
# Parsing page num 3006
# Parsing page num 3007
# Parsing page num 3008
# Parsing page num 3009
# Parsing page num 3010
# Parsing page num 3011
# Parsing page num 3012
# Parsing page num 3013
# Parsing page num 3014
# Parsing page num 3015
# Parsing page num 3016
# Parsing page num 3017
# Parsing page num 3018
# Parsing page num 3019
# Parsing page num 3020
# Parsing page num 3021
# Parsing page num 3022
# Parsing page num 3023
# Parsing page num 3024
# Parsing page num 3025
# Parsing page num 3026
# Parsing page num 3027
# Parsing page num 3028
# Parsing page num 3029
# Parsing page num 3030
# Parsing page num 3031
# Parsing page num 3032
# Parsing page num 3033
# Parsing page num 3034
# Parsing page num 3035
# Parsing page num 3036
# Parsing page num 3037
# Parsing page num 3038
# Parsing page num 3039
# Parsing page num 3040
# Parsing page num 3041
# Parsing page num 3042
# Parsing page num 3043
# Parsing page num 3044
# Parsing page num 3045
# Parsing page num 3046
# Parsing page num 3047
# Parsing page num 3048
# Parsing page num 3049
# Parsing page num 3050
# Parsing page num 3051
# Parsing page num 3052
# Parsing page num 3053
# Parsing page num 3054
# Parsing page num 3055
# Parsing page num 3056
# Parsing page num 3057
# Parsing page num 3058
# Parsing page num 3059
# Parsing page num 3060
# Parsing page num 3061
# Parsing page num 3062
# Parsing page num 3063
# Parsing page num 3064
# Parsing page num 3065
# Parsing page num 3066
# Parsing page num 3067
# Parsing page num 3068
# Parsing page num 3069
# Parsing page num 3070
# Parsing page num 3071
# Parsing page num 3072
# Parsing page num 3073
# Parsing page num 3074
# Parsing page num 3075
# Parsing page num 3076
# Parsing page num 3077
# Parsing page num 3078
# Parsing page num 3079
# Parsing page num 3080
# Parsing page num 3081
# Parsing page num 3082
# Parsing page num 3083
# Parsing page num 3084
# Parsing page num 3085
# Parsing page num 3086
# Parsing page num 3087
# Parsing page num 3088
# Parsing page num 3089
# Parsing page num 3090
# Parsing page num 3091
# Parsing page num 3092
# Parsing page num 3093
# Parsing page num 3094
# Parsing page num 3095
# Parsing page num 3096
# Parsing page num 3097
# Parsing page num 3098
# Parsing page num 3099
# Parsing page num 3100
# Parsing page num 3101
# Parsing page num 3102
# Parsing page num 3103
# Parsing page num 3104
# Parsing page num 3105
# Parsing page num 3106
# Parsing page num 3107
# Parsing page num 3108
# Parsing page num 3109
# Parsing page num 3110
# Parsing page num 3111
# Parsing page num 3112
# Parsing page num 3113
# Parsing page num 3114
# Parsing page num 3115
# Parsing page num 3116
# Parsing page num 3117
# Parsing page num 3118
# Parsing page num 3119
# Parsing page num 3120
# Parsing page num 3121
# Parsing page num 3122
# Parsing page num 3123
# Parsing page num 3124
# Parsing page num 3125
# Parsing page num 3126
# Parsing page num 3127
# Parsing page num 3128
# Parsing page num 3129
# Parsing page num 3130
# Parsing page num 3131
# Parsing page num 3132
# Parsing page num 3133
# Parsing page num 3134
# Parsing page num 3135
# Parsing page num 3136
# Parsing page num 3137
# Parsing page num 3138
# Parsing page num 3139
# Parsing page num 3140
# Parsing page num 3141
# Parsing page num 3142
# Parsing page num 3143
# Parsing page num 3144
# Parsing page num 3145
# Parsing page num 3146
# Parsing page num 3147
# Parsing page num 3148
# Parsing page num 3149
# Parsing page num 3150
# Parsing page num 3151
# Parsing page num 3152
# Parsing page num 3153
# Parsing page num 3154
# Parsing page num 3155
# Parsing page num 3156
# Parsing page num 3157
# Parsing page num 3158
# Parsing page num 3159
# Parsing page num 3160
# Parsing page num 3161
# Parsing page num 3162
# Parsing page num 3163
# Parsing page num 3164
# Parsing page num 3165
# Parsing page num 3166
# Parsing page num 3167
# Parsing page num 3168
# Parsing page num 3169
# Parsing page num 3170
# Parsing page num 3171
# Parsing page num 3172
# Parsing page num 3173
# Parsing page num 3174
# Parsing page num 3175
# Parsing page num 3176
# Parsing page num 3177
# Parsing page num 3178
# Parsing page num 3179
# Parsing page num 3180
# Parsing page num 3181
# Parsing page num 3182
# Parsing page num 3183
# Parsing page num 3184
# Parsing page num 3185
# Parsing page num 3186
# Parsing page num 3187
# Parsing page num 3188
# Parsing page num 3189
# Parsing page num 3190
# Parsing page num 3191
# Parsing page num 3192
# Parsing page num 3193
# Parsing page num 3194
# Parsing page num 3195
# Parsing page num 3196
# Parsing page num 3197
# Parsing page num 3198
# Parsing page num 3199
# Parsing page num 3200
# Parsing page num 3201
# Parsing page num 3202
# Parsing page num 3203
# Parsing page num 3204
# Parsing page num 3205
# Parsing page num 3206
# Parsing page num 3207
# Parsing page num 3208
# Parsing page num 3209
# Parsing page num 3210
# Parsing page num 3211
# Parsing page num 3212
# Parsing page num 3213
# Parsing page num 3214
# Parsing page num 3215
# Parsing page num 3216
# Parsing page num 3217
# Parsing page num 3218
# Parsing page num 3219
# Parsing page num 3220
# Parsing page num 3221
# Parsing page num 3222
# Parsing page num 3223
# Parsing page num 3224
# Parsing page num 3225
# Parsing page num 3226
# Parsing page num 3227
# Parsing page num 3228
# Parsing page num 3229
# Parsing page num 3230
# Parsing page num 3231
# Parsing page num 3232
# Parsing page num 3233
# Parsing page num 3234
# Parsing page num 3235
# Parsing page num 3236
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [181], line 10
#       8 get_page_data(soup, data_all)
#       9 page += 1
# ---> 10 soup = try_get_page_from_server(page)
#
# Cell In [176], line 9, in try_get_page_from_server(page_num)
#       6 sleep(randint(0, 3) + random()) # чтобы спать случайное число времени и наш айпи не залочили
#       8 link = f'https://www.cian.ru/cat.php?deal_type=sale&engine_version=2&object_type%5B0%5D=100&offer_type=flat&p={page_num}&region=1&room1=1'
# ----> 9 page = requests.get(link, headers={'Browser': 'Firefox'})
#      10 if page.status_code != 200:
#      11     return None
#
# File ~\mambaforge\envs\hock\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\mambaforge\envs\hock\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\mambaforge\envs\hock\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~\mambaforge\envs\hock\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~\mambaforge\envs\hock\lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~\mambaforge\envs\hock\lib\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File ~\mambaforge\envs\hock\lib\site-packages\urllib3\connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     464 try:
#     465     # Trigger any extra validation we need to do.
#     466     try:
# --> 467         self._validate_conn(conn)
#     468     except (SocketTimeout, BaseSSLError) as e:
#     469         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~\mambaforge\envs\hock\lib\site-packages\urllib3\connectionpool.py:1092, in HTTPSConnectionPool._validate_conn(self, conn)
#    1090 # Force connect early to allow us to validate the connection.
#    1091 if conn.is_closed:
# -> 1092     conn.connect()
#    1094 if not conn.is_verified:
#    1095     warnings.warn(
#    1096         (
#    1097             f"Unverified HTTPS request is being made to host '{conn.host}'. "
#    (...)
#    1102         InsecureRequestWarning,
#    1103     )
#
# File ~\mambaforge\envs\hock\lib\site-packages\urllib3\connection.py:635, in HTTPSConnection.connect(self)
#     626 if is_time_off:
#     627     warnings.warn(
#     628         (
#     629             f"System time is way off (before {RECENT_DATE}). This will probably "
#    (...)
#     632         SystemTimeWarning,
#     633     )
# --> 635 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     636     sock=sock,
#     637     cert_reqs=self.cert_reqs,
#     638     ssl_version=self.ssl_version,
#     639     ssl_minimum_version=self.ssl_minimum_version,
#     640     ssl_maximum_version=self.ssl_maximum_version,
#     641     ca_certs=self.ca_certs,
#     642     ca_cert_dir=self.ca_cert_dir,
#     643     ca_cert_data=self.ca_cert_data,
#     644     cert_file=self.cert_file,
#     645     key_file=self.key_file,
#     646     key_password=self.key_password,
#     647     server_hostname=server_hostname,
#     648     ssl_context=self.ssl_context,
#     649     tls_in_tls=tls_in_tls,
#     650     assert_hostname=self.assert_hostname,
#     651     assert_fingerprint=self.assert_fingerprint,
#     652 )
#     653 self.sock = sock_and_verified.socket
#     654 self.is_verified = sock_and_verified.is_verified
#
# File ~\mambaforge\envs\hock\lib\site-packages\urllib3\connection.py:774, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     771     if is_ipaddress(normalized):
#     772         server_hostname = normalized
# --> 774 ssl_sock = ssl_wrap_socket(
#     775     sock=sock,
#     776     keyfile=key_file,
#     777     certfile=cert_file,
#     778     key_password=key_password,
#     779     ca_certs=ca_certs,
#     780     ca_cert_dir=ca_cert_dir,
#     781     ca_cert_data=ca_cert_data,
#     782     server_hostname=server_hostname,
#     783     ssl_context=context,
#     784     tls_in_tls=tls_in_tls,
#     785 )
#     787 try:
#     788     if assert_fingerprint:
#
# File ~\mambaforge\envs\hock\lib\site-packages\urllib3\util\ssl_.py:459, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     456 except NotImplementedError:  # Defensive: in CI, we always have set_alpn_protocols
#     457     pass
# --> 459 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     460 return ssl_sock
#
# File ~\mambaforge\envs\hock\lib\site-packages\urllib3\util\ssl_.py:503, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     500     SSLTransport._validate_ssl_context_for_tls_in_tls(ssl_context)
#     501     return SSLTransport(sock, ssl_context, server_hostname)
# --> 503 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File ~\mambaforge\envs\hock\lib\ssl.py:501, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     495 def wrap_socket(self, sock, server_side=False,
#     496                 do_handshake_on_connect=True,
#     497                 suppress_ragged_eofs=True,
#     498                 server_hostname=None, session=None):
#     499     # SSLSocket class handles server_hostname encoding before it calls
#     500     # ctx._wrap_socket()
# --> 501     return self.sslsocket_class._create(
#     502         sock=sock,
#     503         server_side=server_side,
#     504         do_handshake_on_connect=do_handshake_on_connect,
#     505         suppress_ragged_eofs=suppress_ragged_eofs,
#     506         server_hostname=server_hostname,
#     507         context=self,
#     508         session=session
#     509     )
#
# File ~\mambaforge\envs\hock\lib\ssl.py:1041, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1038         if timeout == 0.0:
#    1039             # non-blocking
#    1040             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1041         self.do_handshake()
#    1042 except (OSError, ValueError):
#    1043     self.close()
#
# File ~\mambaforge\envs\hock\lib\ssl.py:1310, in SSLSocket.do_handshake(self, block)
#    1308     if timeout == 0.0 and block:
#    1309         self.settimeout(None)
# -> 1310     self._sslobj.do_handshake()
#    1311 finally:
#    1312     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
len(data_all)
# Out:
# 8229

# %%
import pandas as pd

# %%
cols = ['nrooms', 'meters', 'floor', 'floors_total', 'flat_or_appart', "zh_comp", 'deadline', 'to_metro',  'district', 'area', 'metro', 'mainprice', 'price_per_meter', 'otdelka', 'developer']

df = pd.DataFrame(data=data_all, columns=cols)
print(df.shape)
df
# Out:
# (8229, 15)
#      nrooms meters floor floors_total flat_or_appart  \
# 0      None   None  None         None           None
# 1      None   None  None         None           None
# 2         1   51,2    41           66              A
# 3         1   49,8     2           18              F
# 4      None   None  None         None           None
# ...     ...    ...   ...          ...            ...
# 8224   None   None  None         None           None
# 8225      1  44,94     3           24              F
# 8226      1   48,3    12           18              F
# 8227      1   50,2    16           24              F
# 8228      1  53,57     3            6              A
#
#                                  zh_comp                   deadline  \
# 0     ЖК «River Park Towers Кутузовский»                       None
# 1                              ЖК «ÁLIA»  сдача ГК: 2 кв. 2023 года
# 2                       ЖК «NEVA TOWERS»                   дом сдан
# 3               ЖК «Luzhniki Collection»  сдача ГК: 4 кв. 2026 года
# 4                            ЖК «Famous»  сдача ГК: 4 кв. 2023 года
# ...                                  ...                        ...
# 8224                 ЖК «Wellton Towers»                       None
# 8225                   ЖК «Dream Towers»  сдача ГК: 2 кв. 2023 года
# 8226                     ЖК «Бадаевский»  сдача ГК: 4 кв. 2025 года
# 8227     ЖК «HIGH LIFE Летниковская, 11»                       None
# 8228         ЖК «Клубный дом Космо 4/22»                       None
#
#              to_metro district                      area  \
# 0      5 минут пешком      ЗАО          р-н Дорогомилово
# 1      7 минут пешком     СЗАО  р-н Покровское-Стрешнево
# 2     3 минуты пешком      ЦАО           р-н Пресненский
# 3     15 минут пешком      ЦАО             р-н Хамовники
# 4      5 минут пешком      ЗАО        р-н Филевский парк
# ...               ...      ...                       ...
# 8224  10 минут пешком     СЗАО     р-н Хорошево-Мневники
# 8225   5 минут пешком      ЮАО     р-н Нагатинский затон
# 8226  16 минут пешком      ЗАО          р-н Дорогомилово
# 8227   9 минут пешком      ЮАО           р-н Даниловский
# 8228  15 минут пешком      ЦАО         р-н Замоскворечье
#
#                       metro mainprice price_per_meter otdelka  \
# 0                   м. Фили  22450632          524547    None
# 1                м. Спартак  16122800          335472    None
# 2            м. Выставочная  43724800          854000    None
# 3         м. Воробьёвы горы  33471000          672108    None
# 4                   м. Фили  20837134          543908    None
# ...                     ...       ...             ...     ...
# 8224  м. Народное Ополчение  21700000          563636    None
# 8225           м. Технопарк  21396534          476113    None
# 8226            м. Киевская  50232000         1040000    None
# 8227          м. Павелецкая  33159459          660547    None
# 8228       м. Новокузнецкая  49402254          922200    None
#
#                 developer
# 0        Аеон-Девелопмент
# 1                 ASTERUS
# 2                  Тауэрс
# 3        Absolute Premium
# 4                MR Group
# ...                   ...
# 8224                Место
# 8225  Regions Development
# 8226        Capital Group
# 8227               Пионер
# 8228     Галс-Девелопмент
#
# [8229 rows x 15 columns]

# %%
df.to_csv('data_all.tsv', sep='\t', encoding='utf8')
